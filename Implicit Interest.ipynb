# %%
from sympy import symbols, solve

def implicit_interest():
  '''
  :VA   :  Present Value. what I would have paid x1
  :C    :  To be paid per month
  :n    :  number of months
  '''
  VA = float(input ("Present value: "))
  C =  float(input ("To be paid per month: "))
  n = float(input ("Number of months: "))

  x = symbols('x')
  expr = C*(
      (1-(1+x)**(-n))/x
  ) - VA



  sol = solve(expr)

  return sol

# %%
implicit_interest()
# Out:
# Present value: 20000
# To be paid per month: 9000
# Number of months: 3
# [0.166487417264822,
#  -1.35824370863241 - 0.507380529872089*I,
#  -1.35824370863241 + 0.507380529872089*I]

# %%
(0.0567567+1)**12-1
# Out:
# 0.9395461601953912
